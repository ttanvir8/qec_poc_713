# %% [markdown]
# # Pilot dataset EDA
#
# PILOT / NOT FINAL. Final claims require the deferred full production dataset.

# %%
from pathlib import Path

from causaldem_qec.report import build_dataset_eda, display_eda

index = build_dataset_eda(
    Path("data"),
    Path("reports/dataset_eda"),
    sample_seed=713,
    chunk_rounds=4096,
)
display_eda(index)
